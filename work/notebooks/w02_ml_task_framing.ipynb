# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mn1tchA/MLOps/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.
#
# ## 1. My lane as an ML task (type)
#
# **Task Type:** Classification.
#
# **Decision & Action:** We are deciding which page an editor should fix first. The action is an editor prioritizing the flagged content for manual review and updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# **Target:** An observed future drop in actual traffic.
#
# *Note: We cannot use the provided `is_declining_label` because it is derived from `trend_pct` and `trend_direction`. Using a defined rule as a label means the model just learns the formula, not the real world.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# **Metric:** ROC-AUC or precision/recall against the base rate.
#
# **Cost of a wrong call:** Wasted editor hours. If the model flags a page incorrectly (false positive), an editor wastes time reviewing a page that doesn't need fixing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# @title
import pandas as pd


url = 'https://raw.githubusercontent.com/mn1tchA/MLOps/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

# The unit of analysis is one row per pseudonymized content item
print("Unit of Analysis: One row = one pseudonymized content item")

# Display the dataframe to verify the grain
display(df[['content_id', 'client_id', 'ctr', 'trend_pct']].head())
# Out:
# Unit of Analysis: One row = one pseudonymized content item
#              content_id          client_id   ctr  trend_pct
# 0  content_304f48230142  client_f369cb89fc  0.76      -41.4
# 1  content_a1fb4e703a9e  client_4e07408562  0.05      -57.7
# 2  content_9aa793d4d895  client_7f2253d7e2  0.09      -60.9
# 3  content_331d6c4de07b  client_19581e27de  0.49      -13.8
# 4  content_d99b7a2d90ca  client_3fdba35f04  0.13      -34.7

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A plain rule (like "flag if traffic drops 10%") is not enough because the patterns of content decline are too messy to write by hand. Machine learning earns its place here because the data contains many tangled signals that shift over time across different clients and content types.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
